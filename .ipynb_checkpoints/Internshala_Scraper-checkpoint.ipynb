# %%
from selenium import webdriver
import time
base_url = 'https://internshala.com/internships/'
from bs4 import BeautifulSoup
import json
from wordcloud import WordCloud,STOPWORDS
import re
import requests
import matplotlib.pyplot as plt

# %%
driver = webdriver.Chrome(r'C:\Users\ganas\Documents\chromedriver.exe')
driver.get(base_url)
time.sleep(2)
pagesource = driver.page_source
soup = BeautifulSoup(pagesource,'lxml')
driver.close()

# %%
for i in soup.find_all('select',{'id':'select_category'}):
    lst = i.find_all('option')

# %%
data_dict = {}
for i in lst:
    data_dict.update({i.get_text():base_url + i.attrs['value']+'-internship'})

# %%
data_dict
# Out:
# {'.NET Development': 'https://internshala.com/internships/.net%20development-internship',
#  '3D Printing': 'https://internshala.com/internships/3d%20printing-internship',
#  'Accounts': 'https://internshala.com/internships/accounts-internship',
#  'Acting': 'https://internshala.com/internships/acting-internship',
#  'Aerospace Engineering': 'https://internshala.com/internships/aerospace-internship',
#  'Agriculture & Food Engineering': 'https://internshala.com/internships/agriculture%20and%20food%20engineering-internship',
#  'Analytics': 'https://internshala.com/internships/analytics-internship',
#  'Android App Development': 'https://internshala.com/internships/android-internship',
#  'Angular.js Development': 'https://internshala.com/internships/angular.js%20development-internship',
#  'Animation': 'https://internshala.com/internships/animation-internship',
#  'Architecture': 'https://internshala.com/internships/architecture-internship',
#  'Artificial Intelligence (AI)': 'https://internshala.com/internships/artificial%20intelligence%20(ai)-internship',
#  'ASP.NET Development': 'https://internshala.com/internships/asp.net-internship',
#  'Automobile Engineering': 'https://internshala.com/internships/automobile%20engineering-internship',
#  'Backend Development': 'https://internshala.com/internships/backend%20development-internship',
#  'Big Data': 'https://internshala.com/internships/big%20data-internship',
#  'Bioinformatics': 'https://internshala.com/internships/bioinformatics-internship',
#  'Biology': 'https://internshala.com/internships/biology-internship',
#  'Biotechnology Engineering': 'https://internshala.com/internships/biotech-internship',
#  'Blogging': 'https://internshala.com/internships/blogging-internship',
#  'Brand Management': 'https://internshala.com/internships/brand%20management-internship',
#  'CAD Design': 'https://internshala.com/internships/cad%20design-internship',
#  'Campus Ambassador': 'https://internshala.com/internships/campus%20ambassador-internship',
#  'Chartered Accountancy (CA)': 'https://internshala.com/internships/chartered%20accountancy%20(ca)-internship',
#  'Chemical Engineering': 'https://internshala.com/internships/chemical-internship',
#  'Chemistry': 'https://internshala.com/internships/chemistry-internship',
#  'Cinematography': 'https://internshala.com/internships/cinematography-internship',
#  'Civil Engineering': 'https://internshala.com/internships/civil-internship',
#  'Client Servicing': 'https://internshala.com/internships/client%20servicing-internship',
#  'Cloud Computing': 'https://internshala.com/internships/cloud%20computing-internship',
#  'Commerce': 'https://internshala.com/internships/commerce-internship',
#  'Company Secretary (CS)': 'https://internshala.com/internships/company%20secretary%20(cs)-internship',
#  'Computer Science': 'https://internshala.com/internships/computer%20science-internship',
#  'Computer Vision': 'https://internshala.com/internships/computer%20vision-internship',
#  'Content Writing': 'https://internshala.com/internships/content%20writing-internship',
#  'Copywriting': 'https://internshala.com/internships/copywriting-internship',
#  'Creative Writing': 'https://internshala.com/internships/creative%20writing-internship',
#  'Customer Service': 'https://internshala.com/internships/customer%20service-internship',
#  'Cyber Security': 'https://internshala.com/internships/cyber%20security-internship',
#  'Data Entry': 'https://internshala.com/internships/data%20entry-internship',
#  'Data Science': 'https://internshala.com/internships/data%20science-internship',
#  'Database Building': 'https://internshala.com/internships/database%20building-internship',
#  'Design': 'https://internshala.com/internships/design-internship',
#  'Digital Marketing': 'https://internshala.com/internships/digital%20marketing-internship',
#  'Editorial': 'https://internshala.com/internships/editorial-internship',
#  'Electrical Engineering': 'https://internshala.com/internships/electrical-internship',
#  'Electronics Engineering': 'https://internshala.com/internships/electronics-internship',
#  'Embedded Systems': 'https://internshala.com/internships/embedded%20systems-internship',
#  'Energy Science & Engineering': 'https://internshala.com/internships/energy%20science%20and%20engineering-internship',
#  'Engineering': 'https://internshala.com/internships/engineering-internship',
#  'Engineering Design': 'https://internshala.com/internships/engineering%20design-internship',
#  'Environmental Sciences': 'https://internshala.com/internships/environmental%20sciences-internship',
#  'Event Management': 'https://internshala.com/internships/event%20management-internship',
#  'Facebook Marketing': 'https://internshala.com/internships/facebook%20marketing-internship',
#  'Fashion Design': 'https://internshala.com/internships/fashion%20design-internship',
#  'Film Making': 'https://internshala.com/internships/film%20making-internship',
#  'Finance': 'https://internshala.com/internships/finance-internship',
#  'Front End Development': 'https://internshala.com/internships/front%20end%20development-internship',
#  'Full Stack Development': 'https://internshala.com/internships/full%20stack%20development-internship',
#  'Fundraising': 'https://internshala.com/internships/fundraising-internship',
#  'Game Development': 'https://internshala.com/internships/game%20development-internship',
#  'General Management': 'https://internshala.com/internships/general%20management-internship',
#  'Government': 'https://internshala.com/internships/government-internship',
#  'Graphic Design': 'https://internshala.com/internships/graphic%20design-internship',
#  'Hospitality': 'https://internshala.com/internships/hospitality-internship',
#  'Hotel Management': 'https://internshala.com/internships/hotel%20management-internship',
#  'Human Resources (HR)': 'https://internshala.com/internships/hr-internship',
#  'Humanities': 'https://internshala.com/internships/humanities-internship',
#  'Image Processing': 'https://internshala.com/internships/image%20processing-internship',
#  'Industrial & Production Engineering': 'https://internshala.com/internships/industrial%20and%20production%20engineering-internship',
#  'Industrial Design': 'https://internshala.com/internships/industrial%20design-internship',
#  'Information Technology': 'https://internshala.com/internships/information%20technology-internship',
#  'Instrumentation & Control Engineering': 'https://internshala.com/internships/instrumentation%20and%20control%20engineering-internship',
#  'Interior Design': 'https://internshala.com/internships/interior%20design-internship',
#  'Internet of Things (IoT)': 'https://internshala.com/internships/internet%20of%20things%20(iot)-internship',
#  'iOS App Development': 'https://internshala.com/internships/ios-internship',
#  'Java Development': 'https://internshala.com/internships/java-internship',
#  'Javascript Development': 'https://internshala.com/internships/javascript%20development-internship',
#  'Journalism': 'https://internshala.com/internships/journalism-internship',
#  'Law': 'https://internshala.com/internships/law-internship',
#  'Legal Research': 'https://internshala.com/internships/legal%20research-internship',
#  'Machine Learning': 'https://internshala.com/internships/machine%20learning-internship',
#  'Magento Development': 'https://internshala.com/internships/magento%20development-internship',
#  'Manufacturing Engineering': 'https://internshala.com/internships/manufacturing%20engineering-internship',
#  'Market/Business Research': 'https://internshala.com/internships/market%2Fbusiness%20research-internship',
#  'Marketing': 'https://internshala.com/internships/marketing-internship',
#  'Material Science': 'https://internshala.com/internships/material%20science-internship',
#  'Mathematics': 'https://internshala.com/internships/mathematics-internship',
#  'MBA': 'https://internshala.com/internships/mba-internship',
#  'Mechanical Engineering': 'https://internshala.com/internships/mechanical-internship',
#  'Mechatronics': 'https://internshala.com/internships/mechatronics-internship',
#  'Media': 'https://internshala.com/internships/media-internship',
#  'Medicine': 'https://internshala.com/internships/medicine-internship',
#  'Merchandise Design': 'https://internshala.com/internships/merchandise%20design-internship',
#  'Mobile App Development': 'https://internshala.com/internships/mobile%20app%20development-internship',
#  'Motion Graphics': 'https://internshala.com/internships/motion%20graphics-internship',
#  'Naval Architecture and Ocean Engineeering': 'https://internshala.com/internships/naval%20and%20ocean-internship',
#  'Network Engineering': 'https://internshala.com/internships/network%20engineering-internship',
#  'NGO': 'https://internshala.com/internships/ngo-internship',
#  'Node.js Development': 'https://internshala.com/internships/node.js%20development-internship',
#  'Operations': 'https://internshala.com/internships/operations-internship',
#  'Pharmaceutical': 'https://internshala.com/internships/pharmaceutical-internship',
#  'Photography': 'https://internshala.com/internships/photography-internship',
#  'PHP Development': 'https://internshala.com/internships/php%20development-internship',
#  'Physics': 'https://internshala.com/internships/physics-internship',
#  'Political/Economics/Policy Research': 'https://internshala.com/internships/political%2Feconomics%2Fpolicy%20research-internship',
#  'Public Relations (PR)': 'https://internshala.com/internships/pr-internship',
#  'Product Management': 'https://internshala.com/internships/product-internship',
#  'Programming': 'https://internshala.com/internships/programming-internship',
#  'Psychology': 'https://internshala.com/internships/psychology-internship',
#  'Python/Django Development': 'https://internshala.com/internships/python%2Fdjango-internship',
#  'Recruitment': 'https://internshala.com/internships/recruitment-internship',
#  'Robotics': 'https://internshala.com/internships/robotics-internship',
#  'Ruby on Rails': 'https://internshala.com/internships/ruby%20on%20rails-internship',
#  'Sales': 'https://internshala.com/internships/sales-internship',
#  'Science': 'https://internshala.com/internships/science-internship',
#  'Search Engine Optimization (SEO)': 'https://internshala.com/internships/search%20engine%20optimization%20(seo)-internship',
#  'Social Media Marketing': 'https://internshala.com/internships/social%20media%20marketing-internship',
#  'Social Work': 'https://internshala.com/internships/social%20work-internship',
#  'Software Development': 'https://internshala.com/internships/software%20development-internship',
#  'Software Testing': 'https://internshala.com/internships/software%20testing-internship',
#  'Statistics': 'https://internshala.com/internships/statistics-internship',
#  'Strategy': 'https://internshala.com/internships/strategy-internship',
#  'Supply Chain Management (SCM)': 'https://internshala.com/internships/supply%20chain%20management%20(scm)-internship',
#  'Talent Acquisition': 'https://internshala.com/internships/talent%20acquisition-internship',
#  'Teaching': 'https://internshala.com/internships/teaching-internship',
#  'Telecalling': 'https://internshala.com/internships/telecalling-internship',
#  'Travel & Tourism': 'https://internshala.com/internships/travel%20and%20tourism-internship',
#  'UI/UX Design': 'https://internshala.com/internships/ui%2Fux-internship',
#  'Video Making/Editing': 'https://internshala.com/internships/video%20making%2Fediting-internship',
#  'Videography': 'https://internshala.com/internships/videography-internship',
#  'Volunteering': 'https://internshala.com/internships/volunteering-internship',
#  'Web Development': 'https://internshala.com/internships/web%20development-internship',
#  'Wordpress Development': 'https://internshala.com/internships/wordpress%20development-internship'}

# %%
data_dict['Web Development']
# Out:
# 'https://internshala.com/internships/web%20development-internship'

# %%
def get_intern_links(soup):
    links = []
    for link in soup.find_all('div',{'class': 'heading_4_5 profile'}):
        links.append('https://internshala.com' + link.find('a').get('href'))
    
    return links

# %%
def intern_links(cat_dict):
    cont = requests.get(cat_dict)
    soup = BeautifulSoup(cont.text,'lxml')
    
    intern_links = get_intern_links(soup)
    
    if(pages := int(soup.find('span',{'id':'total_pages'}).get_text())) > 1:
        for i in range(2,pages+1):
            data = requests.get(cat_dict+'/page-'+str(i))
            soup2 = BeautifulSoup(data.text,'lxml')
            intern_links.extend(get_intern_links(soup2))
        
    return intern_links

# %%
interns = intern_links(data_dict['3D Printing'])

# %%
interns
# Out:
# ['https://internshala.com/internship/detail/3d-artist-work-from-home-job-internship-at-ybox-media-llp1604067539',
#  'https://internshala.com/internship/detail/3d-modelling-internship-in-indore-at-cubedots-india-private-limited1603957134',
#  'https://internshala.com/internship/detail/3d-artist-blender-maya-work-from-home-job-internship-at-totality-corporation1602572064']

# %%
def remove_html(text):
    lst=[]
    processed = re.sub(re.compile('<[^>]+>|\n'),' ', text)
    return processed

# %%
def get_words_from_links(lst):
    words_desc_list = []
    skills_list = []
    stipend_list = []
    
    for link in lst:
        data = requests.get(link)
        soup = BeautifulSoup(data.text,'lxml')
        raw = soup.find_all('script',{'type':'application/ld+json'})[1].contents[0]
        js = json.loads(raw)['description']
        words = remove_html(js)
        
        words_desc_list.extend(words.lower().strip().split())
        try:
            skills = re.search('Skills required:.+',words).group()
            skills_list.extend(skills.lower().strip().split())
        except:
            pass
        
        stipend = soup.find_all('span',{'class':'stipend'})[0].get_text().strip()
        lst = []
        for i in re.split('-|/',stipend):
            try:
                int(i)
                lst.append(int(i))
            
                
            except:
                pass
            
            

        
        if len(lst) != 0:
            if len(lst) > 1:
                stipend_list.append(sum(lst)/2)
            else:
                stipend_list.extend(lst)
        

            
        
    return words_desc_list,skills_list,stipend_list

# %%
words_desc_list,skills_list,stipend_list = get_words_from_links(interns)

# %%
stopwords = list(STOPWORDS) + ['available','home','job','internship','work','skills','other','perks','candidates','certificate','start','selected','intern','required','duration','apply','responsibilities','duration','stipend','inr','company','interest','working','month','deadline','interests','include','day','relevant','restart','months','women','wanting','days','week','wanting','career','letter','solution','data','solutions']
joined_desc_sentences = ' '.join(words_desc_list)
wordcloud = WordCloud(stopwords=stopwords).generate(joined_desc_sentences)
plt.figure(figsize=(15,8), facecolor = None)
plt.title('Description Wordcloud',fontdict=dict(fontsize=25))
_=plt.imshow(wordcloud)

# %%
#stopwords = list(STOPWORDS) + ['available','home','job','internship','work','skills','other','perks','candidates','certificate','start','selected','intern','required','duration','apply','responsibilities','duration','stipend','inr','company','interest','working','month','deadline','interests','include','day','relevant','restart','months','women','wanting','days','week','wanting','career','letter','solution','data','solutions']
stopwords2 = stopwords+['proficiency','science','written']
joined_skills_sentences = ' '.join(skills_list)
wordcloud = WordCloud(stopwords=stopwords2).generate(joined_skills_sentences)
plt.figure(figsize=(15,8), facecolor = None)
plt.title('Skills Wordcloud',fontdict=dict(fontsize=25))
_=plt.imshow(wordcloud)

# %%
stipend_list
# Out:
# [10000.0, 4000.0, 15000]
